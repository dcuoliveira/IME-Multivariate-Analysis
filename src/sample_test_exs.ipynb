# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ![Captura de Tela 2021-07-09 às 4.30.05 PM.png](attachment:573092a5-017c-4949-8f44-19f31bb576c9.png)

# %% [markdown]
# ![Captura de Tela 2021-07-09 às 4.30.28 PM.png](attachment:a69f123d-862d-4090-ab26-619923a2abfb.png)

# %%
group1 = pd.DataFrame({'group': 1,
                       'X1': [125, 144, 105, 151, 137],
                       'X2': [137, 173, 119, 149, 139],
                       'X3': [121, 147, 125, 128, 109]})
group2 = pd.DataFrame({'group': 2,
                       'X1': [93, 116, 109, 89, 116],
                       'X2': [121, 135, 83, 95, 128],
                       'X3': [107, 106, 100, 83, 100]})

groups_df = pd.concat([group1, group2], axis=0)
groups_df = groups_df.reset_index(drop=True)
groups_df.set_index('group', inplace=True)

scaler = StandardScaler()
print(scaler.fit(data))
StandardScaler()
print(scaler.mean_)
[0.5 0.5]
print(scaler.transform(data))
standardized_groups_df =

# %%
scaler = StandardScaler()
scaler.fit(groups_df)
standardized_groups_df = pd.DataFrame(scaler.transform(groups_df),
                                     columns=groups_df.columns,
                                     index=groups_df.index)

# %% [markdown]
# PCA com dados originais:

# %%
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(groups_df)
print(np.round(pca.components_,1))
print()
print(pca.explained_variance_ratio_)
# Out:
# [[ 0.5  0.7  0.5]
#  [-0.8  0.4  0.4]
#  [ 0.1 -0.6  0.8]]
#
# [0.85546584 0.08368175 0.06085241]

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# 0.9999999999999999

# %% [markdown]
# PCA com dados padronizados

# %%
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(standardized_groups_df)
print(np.round(pca.components_,1))
print()
print(pca.explained_variance_ratio_)
# Out:
# [[ 0.6  0.6  0.6]
#  [-0.7  0.1  0.7]
#  [ 0.4 -0.8  0.5]]
#
# [0.84172878 0.09839234 0.05987888]

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# 1.0

# %% [markdown]
# Notamos que , como esperado, o resultado da analise de componentes principais para ambos os dados originais e padronizados nao apresenta diferenca significativa, isto e', os primeiros tres componentes representam aproximadamente 99% da variancia.
#
# A ausencia de surpresa com relacao ao resultado da analise de componentes principais para os dados originais e padronizados se deve a observacao que para ambas as 3 variaveis medidas para cada um dos grupos apresentar uma escala muito parecida entre si. Isto evita discrpancia de resultado na ACP por vies de escala de uma das variaveis em especifico.
